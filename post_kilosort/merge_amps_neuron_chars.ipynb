# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def return_path(path_to_data, recording):
    recording_folder = '\\'.join([path_to_data, recording])
    return '\\'.join([recording_folder, recording]) + '.csv'

# %%
recordings_to_analyse = ['401a_2018-04-18_16-34-20_NO_CNO',
                         '401a_2018-04-18_17-40-36_CNO']

path_to_data = r'C:\Users\Rory\raw_data\SERT_DREADD\neuron_characteristics'
path_to_amps = r'C:\Users\Rory\raw_data\SERT_DREADD\cluster_channels'

# %%
recording = recordings_to_analyse[0]
file = return_path(path_to_data, recording)
df_chars = pd.read_csv(file, index_col=0)
df_chars.head()
# Out:
#            cv_isi      rate firing_cat regularity_cat neuron_category  \
# cluster
# 9.0      1.453878  0.485548       slow      irregular  slow irregular
# 13.0     5.383196  2.732742       slow      irregular  slow irregular
# 30.0     2.363353  0.081013       slow      irregular  slow irregular
# 65.0     0.780567  1.054992       slow      irregular  slow irregular
# 75.0     2.528050  0.437079       slow      irregular  slow irregular
#
#         condition
# cluster
# 9.0      Baseline
# 13.0     Baseline
# 30.0     Baseline
# 65.0     Baseline
# 75.0     Baseline

# %%
file = return_path(path_to_amps, recording)
df_chans = pd.read_csv(file, index_col=0)
df_chans = df_chans.drop('depth', axis=1)
df_chans.head()
# Out:
#          channel
# cluster
# 9              2
# 13            23
# 30            27
# 65             5
# 75             8

# %%
df = pd.merge(left=df_chars,
              right=df_chans,
              left_index=True, right_index=True)
df.head()
# Out:
#            cv_isi      rate firing_cat regularity_cat neuron_category  \
# cluster
# 9.0      1.453878  0.485548       slow      irregular  slow irregular
# 13.0     5.383196  2.732742       slow      irregular  slow irregular
# 30.0     2.363353  0.081013       slow      irregular  slow irregular
# 65.0     0.780567  1.054992       slow      irregular  slow irregular
# 75.0     2.528050  0.437079       slow      irregular  slow irregular
#
#         condition  channel
# cluster
# 9.0      Baseline        2
# 13.0     Baseline       23
# 30.0     Baseline       27
# 65.0     Baseline        5
# 75.0     Baseline        8
